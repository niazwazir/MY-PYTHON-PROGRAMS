# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('zebra.bmp')
img2 = cv2.imread('butterfly_GT.bmp')

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
print(img1.shape)
# Out:
# (391, 586, 3)

# %%
img1small = cv2.resize(img1,(400,400))

# %%
print(img1small.shape)
# Out:
# (400, 400, 3)

# %%
print(img2.shape)
# Out:
# (256, 256, 3)

# %%
img2small = cv2.resize(img2,(400,400))

# %%
print(img2small.shape)
# Out:
# (400, 400, 3)

# %%
#add = img1small + img2small #OR BELOW COMMAND
Add = cv2.add(img1small,img2small)

# %%
plt.imshow(Add)
