# %%
from keras.models import load_model
from keras.models import Sequential, Model
from keras.layers import Dense, Activation
from keras.layers import Conv2D, MaxPooling2D, Input, Merge, ZeroPadding2D, merge
from keras.preprocessing import image
from scipy.misc import imsave, imread, imresize, toimage
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from IPython.display import Image
Image('C.png')

# %%
from IPython.display import Image
Image('A.png')

# %%
from IPython.display import Image
Image('B.png')

# %%
img_shape = (41, 41, 1)
input_img = Input(shape=(img_shape))
#01 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv1')(input_img)
model = Activation('relu', name='act1')(model)

#02 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv2')(model)
model = Activation('relu', name='act2')(model)

#03 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv3')(model)
model = Activation('relu', name='act3')(model)

#04 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv4')(model)
model = Activation('relu', name='act4')(model)

#05 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv5')(model)
model = Activation('relu', name='act5')(model)

#06 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv6')(model)
model = Activation('relu', name='act6')(model)

#07 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv7')(model)
model = Activation('relu', name='act7')(model)

#08 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv8')(model)
model = Activation('relu', name='act8')(model)

#09 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv9')(model)
model = Activation('relu', name='act9')(model)

#10 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv10')(model)
model = Activation('relu', name='act10')(model)

#11 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv11')(model)
model = Activation('relu', name='act11')(model)

#12 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv12')(model)
model = Activation('relu', name='act12')(model)

#13 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv13')(model)
model = Activation('relu', name='act13')(model)

#14 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv14')(model)
model = Activation('relu', name='act14')(model)

#15 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv15')(model)
model = Activation('relu', name='act15')(model)

#16 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv16')(model)
model = Activation('relu', name='act16')(model)

#17 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv17')(model)
model = Activation('relu', name='act17')(model)

#18 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv18')(model)
model = Activation('relu', name='act18')(model)

#19 LAYER
model = Conv2D(64, (3, 3), padding='same', name='conv19')(model)
model = Activation('relu', name='act19')(model)

#20 LAYER
model = Conv2D(1, (3, 3), padding='same', name='conv20')(model)
model = Activation('relu', name='act20')(model)


res_img = model
output_img = merge([res_img, input_img])
model = Model(input_img, output_img)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:85: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# C:\Anaconda\lib\site-packages\keras\legacy\layers.py:458: UserWarning: The `Merge` layer is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   name=name)

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 41, 41, 1)    0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 41, 41, 64)   640         input_1[0][0]
# __________________________________________________________________________________________________
# act1 (Activation)               (None, 41, 41, 64)   0           conv1[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv2D)                  (None, 41, 41, 64)   36928       act1[0][0]
# __________________________________________________________________________________________________
# act2 (Activation)               (None, 41, 41, 64)   0           conv2[0][0]
# __________________________________________________________________________________________________
# conv3 (Conv2D)                  (None, 41, 41, 64)   36928       act2[0][0]
# __________________________________________________________________________________________________
# act3 (Activation)               (None, 41, 41, 64)   0           conv3[0][0]
# __________________________________________________________________________________________________
# conv4 (Conv2D)                  (None, 41, 41, 64)   36928       act3[0][0]
# __________________________________________________________________________________________________
# act4 (Activation)               (None, 41, 41, 64)   0           conv4[0][0]
# __________________________________________________________________________________________________
# conv5 (Conv2D)                  (None, 41, 41, 64)   36928       act4[0][0]
# __________________________________________________________________________________________________
# act5 (Activation)               (None, 41, 41, 64)   0           conv5[0][0]
# __________________________________________________________________________________________________
# conv6 (Conv2D)                  (None, 41, 41, 64)   36928       act5[0][0]
# __________________________________________________________________________________________________
# act6 (Activation)               (None, 41, 41, 64)   0           conv6[0][0]
# __________________________________________________________________________________________________
# conv7 (Conv2D)                  (None, 41, 41, 64)   36928       act6[0][0]
# __________________________________________________________________________________________________
# act7 (Activation)               (None, 41, 41, 64)   0           conv7[0][0]
# __________________________________________________________________________________________________
# conv8 (Conv2D)                  (None, 41, 41, 64)   36928       act7[0][0]
# __________________________________________________________________________________________________
# act8 (Activation)               (None, 41, 41, 64)   0           conv8[0][0]
# __________________________________________________________________________________________________
# conv9 (Conv2D)                  (None, 41, 41, 64)   36928       act8[0][0]
# __________________________________________________________________________________________________
# act9 (Activation)               (None, 41, 41, 64)   0           conv9[0][0]
# __________________________________________________________________________________________________
# conv10 (Conv2D)                 (None, 41, 41, 64)   36928       act9[0][0]
# __________________________________________________________________________________________________
# act10 (Activation)              (None, 41, 41, 64)   0           conv10[0][0]
# __________________________________________________________________________________________________
# conv11 (Conv2D)                 (None, 41, 41, 64)   36928       act10[0][0]
# __________________________________________________________________________________________________
# act11 (Activation)              (None, 41, 41, 64)   0           conv11[0][0]
# __________________________________________________________________________________________________
# conv12 (Conv2D)                 (None, 41, 41, 64)   36928       act11[0][0]
# __________________________________________________________________________________________________
# act12 (Activation)              (None, 41, 41, 64)   0           conv12[0][0]
# __________________________________________________________________________________________________
# conv13 (Conv2D)                 (None, 41, 41, 64)   36928       act12[0][0]
# __________________________________________________________________________________________________
# act13 (Activation)              (None, 41, 41, 64)   0           conv13[0][0]
# __________________________________________________________________________________________________
# conv14 (Conv2D)                 (None, 41, 41, 64)   36928       act13[0][0]
# __________________________________________________________________________________________________
# act14 (Activation)              (None, 41, 41, 64)   0           conv14[0][0]
# __________________________________________________________________________________________________
# conv15 (Conv2D)                 (None, 41, 41, 64)   36928       act14[0][0]
# __________________________________________________________________________________________________
# act15 (Activation)              (None, 41, 41, 64)   0           conv15[0][0]
# __________________________________________________________________________________________________
# conv16 (Conv2D)                 (None, 41, 41, 64)   36928       act15[0][0]
# __________________________________________________________________________________________________
# act16 (Activation)              (None, 41, 41, 64)   0           conv16[0][0]
# __________________________________________________________________________________________________
# conv17 (Conv2D)                 (None, 41, 41, 64)   36928       act16[0][0]
# __________________________________________________________________________________________________
# act17 (Activation)              (None, 41, 41, 64)   0           conv17[0][0]
# __________________________________________________________________________________________________
# conv18 (Conv2D)                 (None, 41, 41, 64)   36928       act17[0][0]
# __________________________________________________________________________________________________
# act18 (Activation)              (None, 41, 41, 64)   0           conv18[0][0]
# __________________________________________________________________________________________________
# conv19 (Conv2D)                 (None, 41, 41, 64)   36928       act18[0][0]
# __________________________________________________________________________________________________
# act19 (Activation)              (None, 41, 41, 64)   0           conv19[0][0]
# __________________________________________________________________________________________________
# conv20 (Conv2D)                 (None, 41, 41, 1)    577         act19[0][0]
# __________________________________________________________________________________________________
# act20 (Activation)              (None, 41, 41, 1)    0           conv20[0][0]
# __________________________________________________________________________________________________
# merge_1 (Merge)                 (None, 41, 41, 1)    0           act20[0][0]
#                                                                  input_1[0][0]
# ==================================================================================================
# Total params: 665,921
# Trainable params: 665,921
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.load_weights('vdsr_model.h5')
img = image.load_img('Set5/baby_GT.bmp', grayscale=True, target_size=(41, 41, 1))
x = image.img_to_array(img)
x = x.astype('float32') / 255
x = np.expand_dims(x, axis=0)
pred = model.predict(x)
test_img = np.reshape(pred, (41, 41))
imsave('test_img.png', test_img)
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
