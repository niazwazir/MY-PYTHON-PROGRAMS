# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-271356c8-6c19-4ada-8150-bf553535d7f4" name="files[]" multiple disabled />
#      <output id="result-271356c8-6c19-4ada-8150-bf553535d7f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 1.png to 1.png

# %%
from IPython.display import Image
Image('1.png')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-59ab8b39-d9cb-4955-b128-91b3133c7fd9" name="files[]" multiple disabled />
#      <output id="result-59ab8b39-d9cb-4955-b128-91b3133c7fd9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2.png to 2.png

# %%
from IPython.display import Image
Image('2.png')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-155c0573-bb21-48de-a69c-a0c7a8428b5a" name="files[]" multiple disabled />
#      <output id="result-155c0573-bb21-48de-a69c-a0c7a8428b5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 3.png to 3.png

# %%
from IPython.display import Image
Image('3.png')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3bdc52bb-5ee6-4d52-b932-391f8bb62579" name="files[]" multiple disabled />
#      <output id="result-3bdc52bb-5ee6-4d52-b932-391f8bb62579">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 4.png to 4.png

# %%
from IPython.display import Image
Image('4.png')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e885aa13-4e6b-44d9-9810-2d3c6dfe70e7" name="files[]" multiple disabled />
#      <output id="result-e885aa13-4e6b-44d9-9810-2d3c6dfe70e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 5.png to 5.png

# %%
from IPython.display import Image
Image('5.png')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-38203cca-7910-4b56-9286-df7e1068b78d" name="files[]" multiple disabled />
#      <output id="result-38203cca-7910-4b56-9286-df7e1068b78d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 6.png to 6.png

# %%
from IPython.display import Image
Image('6.png')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0bc0edd8-4b80-4318-a284-ed9f9cf440f6" name="files[]" multiple disabled />
#      <output id="result-0bc0edd8-4b80-4318-a284-ed9f9cf440f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 7.png to 7.png

# %%
from IPython.display import Image
Image('7.png')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6d3ce50c-f57b-4516-991a-e9a2567e6362" name="files[]" multiple disabled />
#      <output id="result-6d3ce50c-f57b-4516-991a-e9a2567e6362">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 8.png to 8.png

# %%
from IPython.display import Image
Image('8.png')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d61fa7c6-47c6-42b8-90c9-8d912b23194a" name="files[]" multiple disabled />
#      <output id="result-d61fa7c6-47c6-42b8-90c9-8d912b23194a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 9.png to 9.png

# %%
from IPython.display import Image
Image('9.png')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b5759d2a-b219-4c9a-a089-1890530bb247" name="files[]" multiple disabled />
#      <output id="result-b5759d2a-b219-4c9a-a089-1890530bb247">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 10.png to 10.png

# %%
from IPython.display import Image
Image('10.png')
