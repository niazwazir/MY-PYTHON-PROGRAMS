# %%
import keras
import cv2
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Activation, Convolution2D
import numpy as np
from keras.layers.advanced_activations import PReLU
import matplotlib.pyplot as plt
# Out:
# /home/wazir/.virtualenvs/cv/local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
baby= cv2.imread('Set5/baby_GT.bmp')

# %%
baby.shape
# Out:
# (512, 512, 3)

# %%
def nice_baby_printer(model,baby):
    baby_batch = np.expand_dims(baby,axis=0)
    conv_baby2 = model.predict(baby_batch)
    
    conv_baby2 = np.squeeze(conv_baby2, axis=0)
    print (conv_baby2.shape)
    conv_baby2 = conv_baby2.reshape(conv_baby2.shape[:2])
    
    print (conv_baby2.shape)
    plt.imshow(conv_baby2)

# %%
model = Sequential()
model.add(Convolution2D(1,3,3,input_shape=baby.shape))
model.add(Activation('relu'))
nice_baby_printer(model,baby)
# Out:
# /home/wazir/.virtualenvs/cv/local/lib/python3.5/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(512, 512,...)`
# (510, 510, 1)
# (510, 510)

# %%
model = Sequential()
act = keras.layers.advanced_activations.PReLU(init='zero', weights=None)
model.add(Convolution2D(1,3,3,input_shape=baby.shape))
model.add(act)
nice_baby_printer(model,baby)
# Out:
# /home/wazir/.virtualenvs/cv/local/lib/python3.5/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `PReLU` call to the Keras 2 API: `PReLU(weights=None, alpha_initializer="zero")`
#
# /home/wazir/.virtualenvs/cv/local/lib/python3.5/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(512, 512,...)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# (510, 510, 1)
# (510, 510)

# %%
model = Sequential()
model.add(Convolution2D(1,3,3,input_shape=baby.shape))
model.add(Activation('selu'))
nice_baby_printer(model,baby)
# Out:
# /home/wazir/.virtualenvs/cv/local/lib/python3.5/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(1, (3, 3), input_shape=(512, 512,...)`
# (510, 510, 1)
# (510, 510)
