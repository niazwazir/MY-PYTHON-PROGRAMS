# %%
#CALCULATION OF LEARNABLE PARAMETERS IN CNN MODEL
from IPython.display import Image
Image('B.png')

# %%
from IPython.display import Image
Image('A.png')

# %% [raw]
# https://www.youtube.com/watch?v=gmBfb6LNnZs

# %%
import keras
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense, Flatten
from keras.layers.convolutional import*
from keras.layers.pooling import*
# Out:
# /home/wazir/.virtualenvs/cv/local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [raw]
# # EXPLANATION ABOUT MODEL
# input_shape = (20,20,3)>>> Model has input layer consisting of image of size 20 by 20 with 3 color channels.
# Conv2D(2, kernel_size=(3,3)>>>>  A first convolution layer with 2 filters of size 3 by 3
# Conv2D(3, kernel_size=(3,3) >>> A second convolution Layer with 3 filters of size 3 by 3
# Flatten() >>> Flatten layers is used to Flatten the Convolutional Output
# Dense(2,activation='softmax') >>> A finally Dense Output Layer with 2 nodes

# %% [raw]
# # PADDING
# padding =  same >>> padding same means maintain the dimensions of images as they flow through out the network

# %%
model = Sequential([
    Conv2D(2, kernel_size=(3,3),input_shape=(20,20,3), activation='relu',padding='same'),
    Conv2D(3, kernel_size=(3,3),activation='relu',padding='same'),
    Flatten(),
    Dense(2,activation='softmax')
])
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 20, 20, 2)         56
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 20, 20, 3)         57
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1200)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 2402
# ...
# Total params: 2,515
# Trainable params: 2,515
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [raw]
# Total params = 56 + 57 + 2402 = 2515
