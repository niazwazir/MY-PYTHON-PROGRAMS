# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
#image = mpimg.imread("chelsea-the-cat.png")
image = mpimg.imread("/home/wazir/SRCNN MODEL/SRCNN/Test/Set5/baby_GT.bmp")
plt.imshow(image)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
#image = mpimg.imread("chelsea-the-cat.png")
rgb = mpimg.imread("/home/wazir/SRCNN MODEL/SRCNN/Test/Set5/baby_GT.bmp")

def rgb2gray(rgb):

    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b

    return gray

# %%
plt.imshow(rgb)
plt.show()

# %%
from skimage import color
from skimage import io
import numpy as np
import matplotlib.pyplot as plt

img = color.rgb2gray(io.imread("/home/wazir/SRCNN MODEL/SRCNN/Test/Set5/baby_GT.bmp")
plt.imshow(img)
img
# Out:
#   File "<ipython-input-9-1640b801561d>", line 6
#     plt.imshow(img)
#       ^
# SyntaxError: invalid syntax
