# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('zebra.bmp')

# %%
plt.imshow(img)

# %%
print(img.shape)
# Out:
# (391, 586, 3)

# %%
#391/2 and 586/2 image size is reduced by scale 2 
small = cv2.resize(img,(0,0),fx=1/2,fy=1/2)

# %%
plt.imshow(small)

# %%
print(small.shape)
# Out:
# (196, 293, 3)

# %%
#OR IMAGE REDUCED BY 200 x 200
small1 = cv2.resize(img,(200,200))

# %%
plt.imshow(small1)

# %%
print(small1.shape)
# Out:
# (200, 200, 3)
